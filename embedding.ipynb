# %%
from tensorflow.keras.preprocessing.text import one_hot
# Out:
# WARNING:tensorflow:From c:\ML\Deep Learning\RNN\myenv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
## Sentences

sent =[ 'the glass of milk',
        'the glass of juice',
        'the cup of tea',
        'I am a good boy',
        'I am a good developer',
        'understand the meanining of words',
        'your videos are good'
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meanining of words',
#  'your videos are good']

# %%
## Define the vocabulary size

voc_size = 10000

# %%
## One hot representation

one_hot_repr = [one_hot(words, voc_size) for words in sent]
one_hot_repr
# Out:
# [[9894, 8536, 8125, 8460],
#  [9894, 8536, 8125, 2272],
#  [9894, 8449, 8125, 2865],
#  [2850, 3023, 2915, 9034, 184],
#  [2850, 3023, 2915, 9034, 8289],
#  [5805, 9894, 2790, 8125, 1867],
#  [3522, 5920, 645, 9034]]

# %%
## Word Embedding Representation

from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr, padding='pre', maxlen = sent_length)

print(embedded_docs)
# Out:
# [[   0    0    0    0 9894 8536 8125 8460]
#  [   0    0    0    0 9894 8536 8125 2272]
#  [   0    0    0    0 9894 8449 8125 2865]
#  [   0    0    0 2850 3023 2915 9034  184]
#  [   0    0    0 2850 3023 2915 9034 8289]
#  [   0    0    0 5805 9894 2790 8125 1867]
#  [   0    0    0    0 3522 5920  645 9034]]

# %%
## Feature Representation
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length = sent_length))
model.compile('adam', 'mse')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 1s 692ms/step
# array([[[ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [-0.02163992, -0.02693877, -0.0206319 , -0.01851077,
#           0.04728714, -0.03223554,  0.04266741, -0.04945257,
#          -0.03818426, -0.01681868],
#         [ 0.01613703,  0.04317682,  0.02585191,  0.00563232,
#          -0.00995325,  0.03787446,  0.04838616,  0.04895777,
#           0.00724907, -0.03419268],
#         [-0.04870414,  0.04445192,  0.03134428, -0.0081849 ,
#          -0.01732017, -0.04696863, -0.00110971,  0.03825057,
#           0.01084238,  0.03395759],
#         [ 0.00918003, -0.04560202,  0.04246711,  0.03291887,
#           0.02880294, -0.04723312,  0.03083805,  0.0467283 ,
#          -0.00660614,  0.02567403]],
#
#        [[ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [-0.02163992, -0.02693877, -0.0206319 , -0.01851077,
#           0.04728714, -0.03223554,  0.04266741, -0.04945257,
#          -0.03818426, -0.01681868],
#         [ 0.01613703,  0.04317682,  0.02585191,  0.00563232,
#          -0.00995325,  0.03787446,  0.04838616,  0.04895777,
#           0.00724907, -0.03419268],
#         [-0.04870414,  0.04445192,  0.03134428, -0.0081849 ,
#          -0.01732017, -0.04696863, -0.00110971,  0.03825057,
#           0.01084238,  0.03395759],
#         [ 0.00078672, -0.03268027, -0.04909515, -0.01609455,
#          -0.03111556, -0.02284944,  0.04409284,  0.03251702,
#           0.01864884,  0.03329614]],
#
#        [[ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [-0.02163992, -0.02693877, -0.0206319 , -0.01851077,
#           0.04728714, -0.03223554,  0.04266741, -0.04945257,
#          -0.03818426, -0.01681868],
#         [ 0.04778979, -0.03975846,  0.03623022,  0.00339567,
#           0.02370108,  0.03296823, -0.02246311,  0.03046468,
#          -0.03761114, -0.02458912],
#         [-0.04870414,  0.04445192,  0.03134428, -0.0081849 ,
#          -0.01732017, -0.04696863, -0.00110971,  0.03825057,
#           0.01084238,  0.03395759],
#         [-0.04823921, -0.01466919,  0.04448911,  0.04494872,
#           0.03690431,  0.0009629 , -0.04294363,  0.00616274,
#          -0.00455576, -0.0191469 ]],
#
#        [[ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.03322846, -0.04450012, -0.00865235,  0.00462109,
#           0.01749006, -0.03270286,  0.0450218 ,  0.00089053,
#           0.00992631,  0.02696787],
#         [ 0.03589375, -0.01798782, -0.04453114,  0.03842647,
#           0.01471711,  0.01207634, -0.01041613, -0.01392793,
#           0.04464135,  0.00941205],
#         [ 0.02826479,  0.00730916,  0.03988605, -0.04013741,
#          -0.01745464, -0.01083176,  0.01878544, -0.00569003,
#           0.0444193 ,  0.02766142],
#         [ 0.02353681, -0.04307896,  0.04661763, -0.03362352,
#           0.00168202,  0.01788584,  0.00092132,  0.02158697,
#           0.02703437,  0.02174432],
#         [ 0.01723751,  0.0335166 , -0.00772519,  0.00708101,
#           0.03546722, -0.04574914,  0.03997538, -0.00984133,
#           0.00825926,  0.0203323 ]],
#
#        [[ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.03322846, -0.04450012, -0.00865235,  0.00462109,
#           0.01749006, -0.03270286,  0.0450218 ,  0.00089053,
#           0.00992631,  0.02696787],
#         [ 0.03589375, -0.01798782, -0.04453114,  0.03842647,
#           0.01471711,  0.01207634, -0.01041613, -0.01392793,
#           0.04464135,  0.00941205],
#         [ 0.02826479,  0.00730916,  0.03988605, -0.04013741,
#          -0.01745464, -0.01083176,  0.01878544, -0.00569003,
#           0.0444193 ,  0.02766142],
#         [ 0.02353681, -0.04307896,  0.04661763, -0.03362352,
#           0.00168202,  0.01788584,  0.00092132,  0.02158697,
#           0.02703437,  0.02174432],
#         [ 0.01517181, -0.04773022, -0.04988448, -0.03601475,
#           0.03607214, -0.0257305 ,  0.02166451,  0.02992009,
#           0.01926656,  0.0046314 ]],
#
#        [[ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [-0.03769183,  0.03315473,  0.0271816 , -0.01012661,
#           0.00353981, -0.00480447,  0.0265383 , -0.04197632,
#           0.0236988 , -0.0403441 ],
#         [-0.02163992, -0.02693877, -0.0206319 , -0.01851077,
#           0.04728714, -0.03223554,  0.04266741, -0.04945257,
#          -0.03818426, -0.01681868],
#         [-0.04823474, -0.04321059,  0.01147313,  0.01127336,
#           0.04153142, -0.00724486, -0.04848276,  0.00258752,
#          -0.04513842,  0.00772418],
#         [-0.04870414,  0.04445192,  0.03134428, -0.0081849 ,
#          -0.01732017, -0.04696863, -0.00110971,  0.03825057,
#           0.01084238,  0.03395759],
#         [-0.01667295,  0.03148932, -0.01556168, -0.01476692,
#           0.01191679, -0.01189488, -0.00292661,  0.01865062,
#           0.04130423, -0.04552857]],
#
#        [[ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,
#           0.04100989, -0.00066011, -0.04405366, -0.04787936,
#           0.01210178, -0.04213079],
#         [-0.02714894, -0.01491796,  0.04495895,  0.00726221,
#           0.00853273,  0.0428852 ,  0.04546643,  0.00639486,
#           0.04427354,  0.03489215],
#         [-0.02144793,  0.02879671, -0.04031731, -0.00807233,
#          -0.01953667,  0.04165893,  0.02626364, -0.04855403,
#          -0.04993904, -0.0039723 ],
#         [ 0.01866973, -0.0314283 ,  0.00560124,  0.00921772,
#          -0.01832848,  0.03227191,  0.00327176, -0.01778948,
#           0.01848812, -0.00440338],
#         [ 0.02353681, -0.04307896,  0.04661763, -0.03362352,
#           0.00168202,  0.01788584,  0.00092132,  0.02158697,
#           0.02703437,  0.02174432]]], dtype=float32)

# %%
embedded_docs[0]
# Out:
# array([   0,    0,    0,    0, 9894, 8536, 8125, 8460])

# %%
model.predict(embedded_docs[0])
# Out:
# 1/1 [==============================] - 0s 90ms/step
# array([[ 0.01817619,  0.04065764,  0.00156988, -0.02632991,  0.04100989,
#         -0.00066011, -0.04405366, -0.04787936,  0.01210178, -0.04213079],
#        [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,  0.04100989,
#         -0.00066011, -0.04405366, -0.04787936,  0.01210178, -0.04213079],
#        [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,  0.04100989,
#         -0.00066011, -0.04405366, -0.04787936,  0.01210178, -0.04213079],
#        [ 0.01817619,  0.04065764,  0.00156988, -0.02632991,  0.04100989,
#         -0.00066011, -0.04405366, -0.04787936,  0.01210178, -0.04213079],
#        [-0.02163992, -0.02693877, -0.0206319 , -0.01851077,  0.04728714,
#         -0.03223554,  0.04266741, -0.04945257, -0.03818426, -0.01681868],
#        [ 0.01613703,  0.04317682,  0.02585191,  0.00563232, -0.00995325,
#          0.03787446,  0.04838616,  0.04895777,  0.00724907, -0.03419268],
#        [-0.04870414,  0.04445192,  0.03134428, -0.0081849 , -0.01732017,
#         -0.04696863, -0.00110971,  0.03825057,  0.01084238,  0.03395759],
#        [ 0.00918003, -0.04560202,  0.04246711,  0.03291887,  0.02880294,
#         -0.04723312,  0.03083805,  0.0467283 , -0.00660614,  0.02567403]],
#       dtype=float32)
